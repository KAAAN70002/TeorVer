# %% [markdown]
# # NoteBook 2. ТВ на примере данных о Титанике

# %% [markdown]
# ## Страница 1

# %% [markdown]
# ### Извлечённый текст
#
#
#
#
#
#
# !""#$%&$'(&)%*'$)+*#,)-$./)0+10+$/2113$2/0+)/"+$451"./#,6&0%*))-$/
# .*""*712*89:1+*)1;*9<+3$+1')*;/);2$+)-$3/.2/"-51"./#,6&0=&"#/3)&>3$2/0+)/"+,5
# (/2'&#&./#)/43$2/0+)/"+15+$/2$'&?*4$"*@A*B6*A*B/'2*6C12$'5;*;&"#/3)*0
# 3$2/0+)/"+,5(/2'&#*./#)/43$2/0+)/"+11+$/2$'*?*4$"*2*C/+*>+)*2$*#,)-8%*))-8
# !"+/D)1;%*))-8=EFFGHIJJKKKLMNOOPQLRSTJRSTGQFUFUSVHJFUFNVURJWNFNXHQPQRFYFZNUVLRH[
# \EFFGHIJJKKKLMNOOPQLRSTJRSTGQFUFUSVHJFUFNVURJWNFNXHQPQRFYFZNUVLRH[]
# ^__
# `abcefgh
# i
# jklm
#
# `abcengh
# i
# opqrstuvwxy{puu|}~
# 
# 
# 
# 
#  ¡¢£¤¥¡¦§¨¡©©ª¦
# «¬­®¯°±²³²´³µ²¶·¸¹º»°¼½¤¾¡¿À¡ÁÂª½Ã£Ä¡ÅÆÇÈÉÊËÌÍÎÏÇÐÐÑÒ
#
# ÓÔÕÖ×ØÙÚÛÜÝÞßàáâãåÚßßæçèØ«é
# ê

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 2

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 3

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 4

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 5

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 6

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 7

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 8

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 9

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 10

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 11

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 12

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>

# %% [markdown]
# ## Страница 13

# %% [markdown]
# ### Оригинал страницы
#
# <img src="data:image/png;base64,..." width="900"/>
